# %%
#disable scrollable boxes of output
# %%javascript
IPython.OutputArea.prototype._should_scroll = function(lines) {
    return false;
}

# %%
import numpy as np
import pandas as pd
import plotly.io as pio
import plotly.express as px

# %%
PATH = r'C:\Users\Zurdo\Documents\Rangel\Summer Internship\SI 2021\INR'

df = pd.read_csv(PATH+r'\EIU_demo_countryyear_v1.1.csv')
# print(df.shape) #df shape 2501 x 11
# print(df.columns)

# %% [markdown]
# # About the gapminder dataset
#
# The democracy index is calculated from the 60 indicators, divided into five "sub indexes", which are:
# 1. Electoral pluralism index;
# 2. Government index;
# 3. Political participation index;
# 4. Political culture index;
# 5. Civil liberty index.
# The sub-indexes are based on the sum of scores on roughly 12 indicators per sub-index, converted into a score between 0 and 100.
# (The Economist publishes the index with a scale from 0 to 10, but Gapminder has converted it to 0 to 100 to make it easier to communicate as a percentage.)

# %%
# filter African countries from dataset
is_afr = df['Continent'] == 'Africa'

df_afr = df[is_afr] #764 x 11
# print(df_afr.shape)
# print(df_afr)

# %% [markdown]
# # Change in Democracy 2006-2020 by continent
#
# ## Notes
# 2010 and 2011 appear to have brought some major increases in Democratic score in Africa.
# Those gains, however, are offset by losses in 2013 in places like Lybia and Egypt

# %%
fig = px.scatter(df, x="time",  y="Change in democracy index (EIU)",
                 animation_group='name', color ="Continent", hover_name="name",facet_col='Continent')
                #animation_frame='time',)
fig.update_xaxes(tickangle=45)
fig.add_hline(y=0)
fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1])) #eliminate "name=countryname" convention for each graph.
fig.show()
# Out:
# <div>                            <div id="3ff7c5d4-c8bf-4e5a-ab38-5c5d8019e993" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ff7c5d4-c8bf-4e5a-ab38-5c5d8019e993")) {                    Plotly.newPlot(                        "3ff7c5d4-c8bf-4e5a-ab38-5c5d8019e993",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Continent=Asia<br>time=%{x}<br>Change in democracy index (EIU)=%{y}<extra></extra>", "hovertext": ["Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain"
# ...

# %% [markdown]
# # African Countries Democracy Index (2006-2020)
#
# ## Notes
# Overall, the democracy index of African countries has either remained flat or declined.

# %%
fig = px.line(df_afr, x="time",  y="Democracy index (EIU)",
                 hover_name="name", facet_col='name', facet_col_wrap=6,
                facet_row_spacing=.04,facet_col_spacing=.04, height = 800, width=800,
              title = "African Countries Democracy Index (2006-2020)"
             )
fig.update_xaxes(tickangle=90)
fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1])) #eliminate "name=countryname" convention for each graph.
#fig.update_yaxes(showticklabels=True)

fig.show()

#create label change from 2006 vs 2020, one per graph
# Out:
# <div>                            <div id="d2fd2d7b-e85c-412d-9de6-695b2fcb841f" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2fd2d7b-e85c-412d-9de6-695b2fcb841f")) {                    Plotly.newPlot(                        "d2fd2d7b-e85c-412d-9de6-695b2fcb841f",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>name=Algeria<br>time=%{x}<br>Democracy index (EIU)=%{y}<extra></extra>", "hovertext": ["Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria"], "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2006, 2007, 2008,
# ...

# %%
is_2006 = df_afr['time'] == 2006
df_afr_2006 = df_afr[is_2006]

fig = px.scatter(df_afr_2006, x="name",  y="Democracy index (EIU)",
                 hover_name="name")
fig.update_xaxes(tickangle=45)
fig.update_xaxes(categoryorder='total ascending')

fig.show()
# Out:
# <div>                            <div id="ac7dc92c-c565-4e37-aa39-4dd8d176a1e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac7dc92c-c565-4e37-aa39-4dd8d176a1e5")) {                    Plotly.newPlot(                        "ac7dc92c-c565-4e37-aa39-4dd8d176a1e5",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>name=%{x}<br>Democracy index (EIU)=%{y}<extra></extra>", "hovertext": ["Algeria", "Angola", "Benin", "Botswana", "Burkina Faso", "Burundi", "Cameroon", "Cape Verde", "Central African Republic", "Chad", "Comoros", "Congo, Dem. Rep.", "Congo, Rep.", "Cote d'Ivoire", "Djibouti", "Egypt", "Equatorial Guinea", "Eritrea", "Ethiopia", "Gabon", "Gambia", "Ghana", "Guinea", "Guinea-Bissau", "Kenya", "Lesotho", "Liberia", "Liby
# ...

# %%
is_2020 = df_afr['time'] == 2020
df_afr_2020 = df_afr[is_2020]

fig = px.scatter(df_afr_2020, x="name",  y="Democracy index (EIU)",
                 hover_name="name")
fig.update_xaxes(tickangle=45)
fig.update_xaxes(categoryorder='total ascending')

fig.show()
# Out:
# <div>                            <div id="7580e19a-2284-46e7-a84a-ac10a5755abf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7580e19a-2284-46e7-a84a-ac10a5755abf")) {                    Plotly.newPlot(                        "7580e19a-2284-46e7-a84a-ac10a5755abf",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>name=%{x}<br>Democracy index (EIU)=%{y}<extra></extra>", "hovertext": ["Angola", "Benin", "Botswana", "Burkina Faso", "Burundi", "Cameroon", "Cape Verde", "Central African Republic", "Chad", "Comoros", "Congo, Dem. Rep.", "Congo, Rep.", "Cote d'Ivoire", "Djibouti", "Egypt", "Equatorial Guinea", "Eritrea", "Ethiopia", "Gabon", "Gambia", "Ghana", "Guinea", "Guinea-Bissau", "Kenya", "Lesotho", "Liberia", "Libya", "Madaga
# ...

# %%
fig = px.scatter(df_afr, x="name",  y="Democracy index (EIU)",
                 animation_group='name', hover_name="name",
                 animation_frame='time')
fig.update_xaxes(tickangle=45)
#fig.update_xaxes(categoryorder='total ascending')

fig.show()
# Out:
# <div>                            <div id="dfaa845c-bd80-4a9d-b66d-64dee66b744d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dfaa845c-bd80-4a9d-b66d-64dee66b744d")) {                    Plotly.newPlot(                        "dfaa845c-bd80-4a9d-b66d-64dee66b744d",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>time=2006<br>name=%{x}<br>Democracy index (EIU)=%{y}<extra></extra>", "hovertext": ["Algeria", "Angola", "Benin", "Botswana", "Burkina Faso", "Burundi", "Cameroon", "Cape Verde", "Central African Republic", "Chad", "Comoros", "Congo, Dem. Rep.", "Congo, Rep.", "Cote d'Ivoire", "Djibouti", "Egypt", "Equatorial Guinea", "Eritrea", "Ethiopia", "Gabon", "Gambia", "Ghana", "Guinea", "Guinea-Bissau", "Kenya", "Lesotho", "Li
# ...
